# %% [markdown]
# note: installing pandas destroyed the azimuth pipeline. A new env was created. try using scanpy and not installing to many other frameworks

# %% [markdown]
# # Run Azimuth on the Bin2cell

# %% [markdown]
# this is mainly to confirm that cell type proportions are similar across annotation tools which gives us a little more trust in the results.

# %% [markdown]
# Use the tmp_panhumanpy2 environment

# %%
import panhumanpy as ph
import matplotlib.pyplot as plt
import scanpy as sc
import pandas as pd
from matplotlib.patches import Patch
import json
import numpy as np
# Out:
# 2025-07-25 12:12:45.859905: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-25 12:12:45.863325: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-25 12:12:45.873872: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-25 12:12:45.890919: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-25 12:12:45.895961: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-25 12:12:45.910540: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-25 12:12:47.504567: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
cells_adata_path = "/srv/gstore/projects/p37785/EzPyzBin2CellApp_2025-06-29--17-56-50/Bin2CellApp_Visium_HD_Human_Lung_Cancer_post_Xenium_5K_Experiment2/cdata.h5ad"

method_name = "B2C"

# %%
adata = sc.read_h5ad(cells_adata_path)

# %%
# High-level interface
azimuth = ph.AzimuthNN(adata)
cell_metadata = azimuth.cells_meta
embeddings = azimuth.azimuth_embed()
umap = azimuth.azimuth_umap()
# Out:
# /misc/ngseq12/miniforge3/envs/tmp_panhumanpy2/lib/python3.9/site-packages/panhumanpy/ANNotate.py:1062: UserWarning: Ensure that the features metadata is indexed with gene names.
#   warnings.warn(
# Integer counts detected by panhumanpy.ANNotate : False
# Log-normalization performed by panhumanpy.ANNotate: False
# Query object:
#     Total number of cells: 193856
#     Total number of features: 17959
#     Overlap w. feature reference: 4635 (~91%)
#
# Splitting query data into 24 evaluation batches.
#
# Running model:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753438378.012542 3579459 service.cc:146] XLA service 0x7fd038010720 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753438378.012610 3579459 service.cc:154]   StreamExecutor device (0): Host, Default Version
# 2025-07-25 12:12:58.025935: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#  28/256 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# I0000 00:00:1753438378.299030 3579459 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Extracting azimuth embeddings:
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# /misc/ngseq12/miniforge3/envs/tmp_panhumanpy2/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /misc/ngseq12/miniforge3/envs/tmp_panhumanpy2/lib/python3.9/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.3, n_jobs=1, n_neighbors=30, random_state=42, verbose=True)
# Fri Jul 25 12:14:20 2025 Construct fuzzy simplicial set
# Fri Jul 25 12:14:20 2025 Finding Nearest Neighbors
# Fri Jul 25 12:14:20 2025 Building RP forest with 27 trees
# Fri Jul 25 12:14:26 2025 NN descent for 18 iterations
# 	 1  /  18
# 	 2  /  18
# 	 3  /  18
# 	Stopping threshold met -- exiting after 3 iterations
# Fri Jul 25 12:15:03 2025 Finished Nearest Neighbor Search
# Fri Jul 25 12:15:06 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Fri Jul 25 12:17:21 2025 Finished embedding

# %%
# Add 'final_level_labels' and 'final_level_softmax_prob' from cell_metadata to adata.obs
adata.obs['final_level_labels'] = cell_metadata['final_level_labels']
adata.obs['final_level_softmax_prob'] = cell_metadata['final_level_softmax_prob']

# %%
cell_metadata
# Out:
#                                  full_hierarchical_labels level_zero_labels  \
# 1            Immune cell|Lymphoid cell|B cell|Plasma cell       Immune cell
# 2       Epithelial cell|Epithelial cell of bladder|Bas...   Epithelial cell
# 3       Epithelial cell|Epithelial cell of intestine|G...   Epithelial cell
# 4       Immune cell|Lymphoid cell|B cell|T cell|abT (e...       Immune cell
# 5       Epithelial cell|Epithelial cell of intestine|A...   Epithelial cell
# ...                                                   ...               ...
# 318738  Immune cell|Lymphoid cell|B cell|Plasma cell|C...       Immune cell
# 318739  Immune cell|Lymphoid cell|B cell|T cell|CD4 T ...       Immune cell
# 318741  Immune cell|Lymphoid cell|T/NK cell|T cell|abT...       Immune cell
# 318749  Immune cell|Lymphoid cell|T/NK cell|T cell|CD4...       Immune cell
# 318750  Immune cell|Lymphoid cell|T/NK cell|T cell|abT...       Immune cell
#
#                       final_level_labels  final_level_softmax_prob  \
# 1                            Plasma cell                  0.824416
# 2       DKK1+MMP1+ basal cell of bladder                  0.730892
# 3                            Goblet cell                  0.556046
# 4                       abT (entry) cell                  0.323764
# 5                      Airway basal cell                  0.299084
# ...                                  ...                       ...
# 318738                  Naive CD4 T cell                  0.381444
# 318739                  Naive CD4 T cell                  0.389389
# 318741                  Naive CD4 T cell                  0.434570
# 318749                  Naive CD4 T cell                  0.504090
# 318750                  abT (entry) cell                  0.549620
#
#         full_consistent_hierarchy  object_id  bin_count    array_row  \
# 1                            True          1         39   770.564103
# 2                            True          2         52   909.173077
# 3                            True          3         63   901.079365
# 4                           False          4         50   799.700000
# 5                           False          5         42   847.952381
# ...                           ...        ...        ...          ...
# 318738                      False     318738          4  3299.000000
# 318739                      False     318739          6  3260.666667
# 318741                      False     318741          1  2744.000000
# 318749                       True     318749          3  2873.000000
# 318750                       True     318750          6  3229.333333
#
#           array_col labels_joint_source
# 1       1658.512821             primary
# 2       1819.230769             primary
# 3       1940.031746             primary
# 4       1940.040000             primary
# 5       1837.571429             primary
# ...             ...                 ...
# 318738    34.250000           secondary
# 318739   232.666667           secondary
# 318741   426.000000           secondary
# 318749   395.000000           secondary
# 318750   408.500000           secondary
#
# [193856 rows x 10 columns]

# %%
# High-level interface
#azimuth = ph.AzimuthNN(pbmc3k)
cell_metadata 
#embeddings = azimuth.azimuth_embed()
#umap = azimuth.azimuth_umap()
# Out:
#                                  full_hierarchical_labels level_zero_labels  \
# 1            Immune cell|Lymphoid cell|B cell|Plasma cell       Immune cell
# 2       Epithelial cell|Epithelial cell of bladder|Bas...   Epithelial cell
# 3       Epithelial cell|Epithelial cell of intestine|G...   Epithelial cell
# 4       Immune cell|Lymphoid cell|B cell|T cell|abT (e...       Immune cell
# 5       Epithelial cell|Epithelial cell of intestine|A...   Epithelial cell
# ...                                                   ...               ...
# 318738  Immune cell|Lymphoid cell|B cell|Plasma cell|C...       Immune cell
# 318739  Immune cell|Lymphoid cell|B cell|T cell|CD4 T ...       Immune cell
# 318741  Immune cell|Lymphoid cell|T/NK cell|T cell|abT...       Immune cell
# 318749  Immune cell|Lymphoid cell|T/NK cell|T cell|CD4...       Immune cell
# 318750  Immune cell|Lymphoid cell|T/NK cell|T cell|abT...       Immune cell
#
#                       final_level_labels  final_level_softmax_prob  \
# 1                            Plasma cell                  0.824416
# 2       DKK1+MMP1+ basal cell of bladder                  0.730892
# 3                            Goblet cell                  0.556046
# 4                       abT (entry) cell                  0.323764
# 5                      Airway basal cell                  0.299084
# ...                                  ...                       ...
# 318738                  Naive CD4 T cell                  0.381444
# 318739                  Naive CD4 T cell                  0.389389
# 318741                  Naive CD4 T cell                  0.434570
# 318749                  Naive CD4 T cell                  0.504090
# 318750                  abT (entry) cell                  0.549620
#
#         full_consistent_hierarchy  object_id  bin_count    array_row  \
# 1                            True          1         39   770.564103
# 2                            True          2         52   909.173077
# 3                            True          3         63   901.079365
# 4                           False          4         50   799.700000
# 5                           False          5         42   847.952381
# ...                           ...        ...        ...          ...
# 318738                      False     318738          4  3299.000000
# 318739                      False     318739          6  3260.666667
# 318741                      False     318741          1  2744.000000
# 318749                       True     318749          3  2873.000000
# 318750                       True     318750          6  3229.333333
#
#           array_col labels_joint_source
# 1       1658.512821             primary
# 2       1819.230769             primary
# 3       1940.031746             primary
# 4       1940.040000             primary
# 5       1837.571429             primary
# ...             ...                 ...
# 318738    34.250000           secondary
# 318739   232.666667           secondary
# 318741   426.000000           secondary
# 318749   395.000000           secondary
# 318750   408.500000           secondary
#
# [193856 rows x 10 columns]

# %%
# Calculate mean, median, and total number of cells
mean_conf_score = cell_metadata['final_level_softmax_prob'].mean()
median_conf_score = cell_metadata['final_level_softmax_prob'].median()
total_cells = cell_metadata['final_level_softmax_prob'].shape[0]

# Plot histogram
cell_metadata['final_level_softmax_prob'].hist(bins=50, figsize=(10, 6), alpha=0.7, label='Confidence Scores')
plt.axvline(mean_conf_score, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean: {mean_conf_score:.6f}')
plt.axvline(median_conf_score, color='blue', linestyle='dashed', linewidth=1.5, label=f'Median: {median_conf_score:.6f}')
plt.title('Distribution of Softmax Scores')
plt.xlabel('final lvl Softmax Score')
plt.ylabel('Frequency')
plt.legend()

# Display summary metrics
num_scores_above_90 = (cell_metadata['final_level_softmax_prob'] > 0.9).sum()
summary_text = (
    f"Min: {cell_metadata['final_level_softmax_prob'].min():.6f}\n"
    f"Max: {cell_metadata['final_level_softmax_prob'].max():.6f}\n"
    f"Total Cells: {total_cells}\n"
    f"Scores > 90%: {num_scores_above_90}"
)
plt.figtext(0.2, 0.4, summary_text, fontsize=10, bbox={"facecolor": "white", "alpha": 0.5, "pad": 5})

plt.show()

# %%
# Create the plot
plt.figure(figsize=(10, 10))
plt.scatter(
    adata.obsm['spatial'][:,0],
    adata.obsm['spatial'][:,1],
    s=1,
    alpha=0.5,
    c=adata.obs['final_level_softmax_prob'],
    cmap='viridis',
    label='Cells'
)
plt.colorbar(label='Confidence Score')

# Add labels and legend
plt.title('Dotplot of Cells colored by Confidence')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.legend()
plt.show()

# %%
cell_type_counts = cell_metadata['level_zero_labels'].value_counts().reset_index()
cell_type_counts.columns = ["Cell Type", "Count"]

# Create the plot
plt.figure(figsize=(10, 6))
plt.bar(cell_type_counts["Cell Type"], cell_type_counts["Count"], color='skyblue')
plt.title("Distribution of Cell Types", fontsize=16)
plt.xlabel("Cell Type", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
cell_type_counts = cell_metadata['final_level_labels'].value_counts().nlargest(40).reset_index()
cell_type_counts.columns = ["Cell Type", "Count"]

# Create the plot
plt.figure(figsize=(12, 8))  # Adjusted figure size for better readability
plt.bar(cell_type_counts["Cell Type"], cell_type_counts["Count"], color='skyblue')
plt.title("Distribution of Top 25 Cell Types", fontsize=16)  # Updated title
plt.xlabel("Cell Type", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45, ha="right", fontsize=10)  # Adjusted rotation and font size
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import json

# Load mapping from Azimuth cell types to simplified categories
with open('azimuth_to_simplified_mapping.json', 'r') as f:
    azimuth_to_simplified = json.load(f)

def map_cell_type(cell_type):
    return azimuth_to_simplified.get(cell_type, 'other')

print("Mapping preview:")
for azimuth_type, simplified_type in list(azimuth_to_simplified.items())[:10]:
    print(f"  {azimuth_type} -> {simplified_type}")

print(f"\nTotal mapped cell types: {len(azimuth_to_simplified)}")
print("Any unmapped cell types will be assigned to 'other'")
# Out:
# Mapping preview:
#   Alveolar macrophage -> Macro
#   Macrophage -> Macro
#   M1 macrophage -> Macro
#   LYVE1 macrophage -> Macro
#   CD14 monocyte -> Monocyte
#   Monocyte -> Monocyte
#   CD16 monocyte -> Monocyte
#   Memory CD4 T cell -> CD4
#   CD4 T cell -> CD4
#   Naive CD4 T cell -> CD4
#
# Total mapped cell types: 40
# Any unmapped cell types will be assigned to 'other'

# %%
# Apply the mapping to create simplified cell type categories
cell_metadata['simplified_cell_type'] = cell_metadata['final_level_labels'].apply(map_cell_type)
adata.obs['simplified_cell_type'] = cell_metadata['simplified_cell_type']
# Create simplified cell type counts
simplified_counts = cell_metadata['simplified_cell_type'].value_counts().reset_index()
simplified_counts.columns = ["Cell Type", "Count"]

# Calculate proportions
simplified_counts['Proportion'] = simplified_counts['Count'] / simplified_counts['Count'].sum()

# %%
# Load the CSV file
azimuth_prop_df = pd.read_csv('azimuth_proportions.csv')

# Append the computed proportions from simplified_counts
azimuth_prop_df = azimuth_prop_df.merge(
    simplified_counts[['Cell Type', 'Proportion']],
    on='Cell Type',
    how='left'
)
azimuth_prop_df = azimuth_prop_df.rename(columns={'Proportion': method_name})

# Save the updated dataframe
azimuth_prop_df.to_csv('azimuth_proportions.csv', index=False)

azimuth_prop_df.head()
# Out:
#    Cell Type        SC     Enact    Bin8x8       B2C
# 0      Macro  0.267499  0.001585  0.006952  0.001083
# 1        CD4  0.152752  0.206224  0.158819  0.262736
# 2  Secretory  0.106869  0.068305  0.085772  0.058229
# 3        CD8  0.101322  0.001002  0.003049  0.000733
# 4      other  0.095014  0.180889  0.282833  0.171658

# %%
label_list = ["AT1", "AT2", "B","Basal", "CD4", "CD8","Ciliated","DC", "Endothelia", "Fibro",
"Macro","Mast","Monocyte", "NKT","NK","Secretory", "T" , "other"] 

colors = plt.cm.tab20.colors  # Use a colormap with enough distinct colors
cell_types = np.sort(label_list)

# Assign a color to each cell type
color_map = {cell_type: colors[i % len(colors)] for i, cell_type in enumerate(cell_types)}
# Plot the spatial scatter as before
plt.figure(figsize=(12, 10))
plt.scatter(
    adata.obsm['spatial'][:,0],
    adata.obsm['spatial'][:,1],
    s=2,
    alpha=0.5,
    c=[color_map[cell_type] for cell_type in adata.obs["simplified_cell_type"]],
    label='Cells'
)

plt.title('Dotplot of Cells colored by Broad Cell Type')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')

# Create custom legend
legend_elements = [
    Patch(facecolor=color_map[cell_type], label=cell_type)
    for cell_type in cell_types
]
plt.legend(handles=legend_elements, title="Broad Cell Type", bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.tight_layout()
plt.show()
