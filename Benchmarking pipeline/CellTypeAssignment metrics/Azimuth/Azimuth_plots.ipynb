# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
azimuth_df = pd.read_csv('/home/degottardiraphael/MasterThesis/Benchmarking pipeline/CellTypeAssignment metrics/Azimuth/azimuth_proportions.csv', index_col=0)
azimuth_df
# Out:
#                   SC    Bin8x8     Enact       B2C      Xseg
# Cell Type
# AT1         0.005192  0.000058  0.000064  0.000062  0.000189
# AT2         0.014542  0.003514  0.005546  0.004627  0.007987
# B           0.050165  0.434017  0.470264  0.430500  0.417567
# Basal       0.000000  0.000000  0.000000  0.000000  0.000000
# CD4         0.152752  0.158819  0.206224  0.262736  0.257139
# CD8         0.101322  0.003049  0.001002  0.000733  0.000980
# Ciliated    0.012971  0.000165  0.000000  0.000000  0.000000
# DC          0.038996  0.002021  0.000329  0.000253  0.000499
# Endothelia  0.011839  0.002804  0.000011  0.000021  0.000012
# Fibro       0.004282  0.000056  0.000005       NaN  0.000006
# Macro       0.267499  0.006952  0.001585  0.001083  0.002191
# Mast        0.016543  0.000540  0.000011  0.000026  0.000043
# Monocyte    0.055787  0.000088  0.000064  0.000036  0.000049
# NK          0.052637  0.000000  0.000000  0.000000  0.000000
# ...

# %%
label_list = ["AT1", "AT2", "B","Basal", "CD4", "CD8","Ciliated","DC", "Endothelia", "Fibro",
"Macro","Mast","Monocyte", "NK","NKT","Secretory", "T" , "other"] 

azimuth_df = azimuth_df.rename(columns={'SC': 'scRNA-seq'})
colors = plt.cm.tab20.colors  # Use a colormap with enough distinct colors
cell_types = np.sort(label_list)
azimuth_df = azimuth_df.sort_index()

# Assign a color to each cell type
color_map = {cell_type: colors[i % len(colors)] for i, cell_type in enumerate(cell_types)}

ax = azimuth_df.T.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 6),
    color=[color_map[ct] for ct in cell_types]
)

plt.ylabel('Proportion')
plt.title('Cell Type Proportions Across Methods')
plt.legend(title='Cell Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
